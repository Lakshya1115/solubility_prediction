# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshya1115/solubility_prediction/blob/main/solubility_prediction_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MY FIRST MODEL**

# %% [markdown]
# # **Loading the dataset**

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/delaney_solubility_with_descriptors.csv')
df
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Data Separation as X and Y**

# %%
y = df['logS']
y
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
x = df.drop('logS', axis=1)
x
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %% [markdown]
# ## **Data Splitting**

# %%
from sklearn.model_selection import train_test_split

x_test, x_train, y_test, y_train = train_test_split(x, y, train_size = 0.2, random_state=100)

# %%
y_train
# Out:
# 822    -3.380
# 118    -8.010
# 347    -2.160
# 1123   -1.170
# 924    -0.730
#         ...
# 984    -2.478
# 497    -1.060
# 296    -5.160
# 294    -0.510
# 544    -2.100
# Name: logS, Length: 916, dtype: float64

# %%
y_test
# Out:
# 466   -1.370
# 304   -4.678
# 781    0.358
# 971   -2.370
# 123   -8.940
#        ...
# 802   -2.925
# 53    -2.680
# 350   -7.020
# 79    -4.800
# 792   -3.240
# Name: logS, Length: 228, dtype: float64

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## **Linear Regression**

# %% [markdown]
# ### **Training the model**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Applying the model to make predictions**

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
y_lr_test_pred
# Out:
# array([-1.08577354, -4.70604627,  1.84561218, -1.81297855, -8.46707731,
#        -4.32842076, -1.13394175, -2.18636038, -1.87999866, -1.80147836,
#        -9.15936719, -3.63710451, -2.29712844, -0.67299983, -7.35540732,
#        -2.1653826 , -1.90874112, -1.71940222, -4.39682692, -1.91181368,
#        -5.32365923, -3.70593284, -3.38387782, -3.86042997, -3.88049195,
#        -1.78334896, -2.89003732, -1.88922435, -3.9812208 , -2.44267603,
#        -4.16755953, -0.55682921, -2.75726556, -2.07323895, -1.58348597,
# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print("LR TRAIN MSE: ", lr_train_mse)
print("LR TRAIN R2: ", lr_train_r2)
print("LR TEST MSE: ", lr_test_mse)
print("LR TEST R2: ", lr_test_r2)
# Out:
# LR TRAIN MSE:  1.0579642204473312
# LR TRAIN R2:  0.759096382953972
# LR TEST MSE:  0.8246237995388787
# LR TEST R2:  0.8119021943129568

# %%
lr_results = pd.DataFrame(['Linear Regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ["Method", "Train MSE", "Train R2", "Test MSE", "Test R2"]
lr_results
# Out:
#               Method Train MSE  Train R2  Test MSE   Test R2
# 0  Linear Regression  1.057964  0.759096  0.824624  0.811902

# %% [markdown]
# ## **Random Forsest**

# %% [markdown]
# ### **Training the model**

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth = 2, random_state = 100)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ### **Applying the model to make predictions**

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %%
y_rf_test_pred
# Out:
# array([-1.21827036, -4.12785933, -1.62726401, -1.40097609, -6.93584901,
#        -4.36977104, -1.21827036, -2.35969384, -2.2533737 , -2.09422382,
#        -6.93584901, -4.36977104, -1.52561721, -1.62726401, -6.93584901,
#        -1.48788712, -1.40097609, -2.03395977, -2.69654245, -1.34652608,
#        -4.36977104, -4.36977104, -2.68003855, -4.07987264, -3.05091746,
#        -1.62726401, -1.64044856, -1.62726401, -2.68003855, -3.45843651,
#        -4.09216765, -1.42947535, -2.89172836, -1.4532635 , -1.40097609,
#        -2.45769932, -1.62726401, -1.21827036, -4.35285726, -1.21827036,
#        -2.46801534, -2.04870567, -1.62726401, -3.51584094, -6.93584901,
#        -1.4152408 , -1.21827036, -1.4152408 , -1.64043156, -4.36977104,
#        -1.63078942, -1.62726401, -1.21827036, -2.60201852, -4.22704577,
#        -6.93584901, -5.14840968, -4.36977104, -2.2533737 , -2.67797453,
#        -5.27134231, -1.21827036, -6.93584901, -4.12785933, -2.64734126,
#        -2.30090745, -1.21827036, -2.5293722 , -4.09216765, -5.27134231,
#        -4.36977104, -1.62726401, -3.36509254, -1.21827036, -2.04870567,
#        -2.5293722 , -6.9073465 , -2.79991102, -2.59928868, -1.65358206,
#        -4.36977104, -6.93584901, -1.21827036, -4.36977104, -2.94563408,
#        -5.27134231, -4.07987264, -2.68003855, -2.43295112, -2.69654245,
#        -6.9073465 , -1.21827036, -2.85825035, -1.75100987, -1.44155885,
#        -1.32713556, -2.63247954, -2.0800465 , -4.36977104, -2.2533737 ,
#        -2.08020624, -2.7621882 , -1.62726401, -4.22704577, -6.93584901,
#        -2.51526112, -6.93584901, -4.58266438, -2.61821484, -3.45843651,
#        -6.93584901, -2.63247954, -2.45034414, -4.29822575, -6.93584901,
#        -1.21827036, -1.32713556, -4.14430719, -2.3081081 , -5.27134231,
#        -1.21827036, -5.27134231, -4.29822575, -2.03395977, -4.09216765,
#        -2.39759057, -6.93584901, -1.21827036, -1.21827036, -3.42583176,
#        -4.36977104, -4.09216765, -2.30090745, -2.79991102, -1.4152408 ,
#        -2.79991102, -4.12785933, -1.53464756, -2.78374383, -2.48224989,
#        -1.21827036, -5.27134231, -4.29822575, -2.03395977, -4.09216765,
#        -2.39759057, -6.93584901, -1.21827036, -1.21827036, -3.42583176,
#        -4.36977104, -4.09216765, -2.30090745, -2.79991102, -1.4152408 ,
#        -2.79991102, -4.12785933, -1.53464756, -2.78374383, -2.48224989,
#        -1.2314549 , -3.40134838, -4.36977104, -2.19155236, -1.21827036,
#        -4.12785933, -1.62726401, -1.21827036, -1.32713556, -1.73612921,
#        -1.62726401, -3.76818942, -4.12785933, -1.62726401, -1.75100987,
#        -1.46998225, -1.21827036, -4.2780373 , -1.67121258, -1.21827036,
#        -1.62726401, -6.93584901, -2.7621882 , -2.23598067, -4.12785933,
#        -2.27104489, -1.32713556, -2.04870567, -1.62726401, -4.16005868,
#        -1.44206041, -4.36977104, -2.27104489, -1.21827036, -5.27134231,
#        -6.93584901, -1.50984129, -5.27134231, -1.40097609, -1.40097609,
#        -4.2780373 , -2.7202414 , -3.76818942, -1.21827036, -4.36977104,
#        -4.36977104, -1.5508361 , -2.03395977, -2.46801534, -1.4152408 ,
#        -4.22704577, -1.21827036, -4.36977104, -4.36977104, -1.8475253 ,
#        -6.27952737, -2.29198826, -4.36977104, -4.36977104, -2.64497433,
#        -4.2780373 , -4.09216765, -2.63247954, -1.21827036, -1.62726401,
#        -1.42947535, -4.10959731, -4.36977104, -4.36977104, -2.84781825,
#        -1.21827036, -4.36977104, -6.9073465 , -1.50984129, -1.40097609,
#        -1.31441221, -5.37957593, -2.27104489, -2.69654245, -6.93584901,
#        -4.36977104, -1.45741144, -2.83001835, -4.09216765, -2.23598067,
#        -6.93584901, -4.36977104, -2.72630718])

# %% [markdown]
# ### **Evaluate Model Performance**

# %%
rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random Forest Regression', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ["Method", "Train MSE", "Train R2", "Test MSE", "Test R2"]
rf_results
# Out:
#                      Method Train MSE  Train R2  Test MSE   Test R2
# 0  Random Forest Regression   1.03469  0.764396  0.916325  0.790985

# %% [markdown]
# # **Comparing the results**

# %% [markdown]
# ## **Tabular Comparison**

# %%
result_table = pd.concat([lr_results, rf_results], ignore_index = True, axis=0).reset_index(drop=True)
result_table
# Out:
#                      Method Train MSE  Train R2  Test MSE   Test R2
# 0         Linear Regression  1.057964  0.759096  0.824624  0.811902
# 1  Random Forest Regression   1.03469  0.764396  0.916325  0.790985

# %% [markdown]
# ## **Data Visualisation of Predicted Data**

# %%
import matplotlib.pyplot as plt
import numpy as np

## plt.figure(figsize = (5, 5))
plt.scatter(x = y_train, y = y_lr_train_pred, alpha=0.3, c = '#0000ff')

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.title('Linear Regression: Predicted vs. Experimental LogS', fontsize=16)
plt.xlabel('Experimental LogS')
plt.ylabel('Predicted LogS')
plt.plot(y_train, p(y_train), '#ff0000')

# %%
import matplotlib.pyplot as plt
import numpy as np

## plt.figure(figsize = (5, 5))
plt.scatter(x = y_train, y = y_rf_train_pred, alpha=0.3, c = '#0000ff')

z = np.polyfit(y_train, y_rf_train_pred, 1)
p = np.poly1d(z)

plt.title('Random Forest: Predicted vs. Experimental LogS', fontsize=16)
plt.xlabel('Experimental LogS')
plt.ylabel('Predicted LogS')
plt.plot(y_train, p(y_train), '#ff0000')
